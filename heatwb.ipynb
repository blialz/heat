# %% [markdown]
# # Équivalence CO2 - Wellby, vis à vis de la chaleur

# %% [markdown]
# ## Introduction
#
# Dans ce document, nous tenterons d'estimer un ordre de grandeur de l'impact du changement (et en l'occurence du réchauffement) climatique sur le bien-être humain, notamment par le biais du malaise dû aux fortes chaleurs.
#
# Dans un premier temps, nous nous baserons sur les travaux de [Noelke et al.](https://www.sciencedirect.com/science/article/abs/pii/S001393511630281X)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Grosse étude au sujet de la mortalité des vagues de chaleur et de leur caracère récurrent : [MOra et al, 2017](https://www.nature.com/articles/nclimate3322)

# %% [markdown]
# Cet article nous informe que d'ici à 2100, et selon un scénario RCP 4.5, la proportion de la population mondiale exposée à des condition de température et d'humidité mortelles pendant plus de 20 jours par an sera de plus de 50% (comparé à 30% en 1975)
#
# Une estimation conservative des Wellbys perdus serait donc:
#
# $$ \

# %% [markdown]
# Standy sur le dernier bloc : l'étude précédente ne propose pas de métrique en jours passés, mais seulement en proportion de la population avec plus de 20 jours dans l'année ou alors en jours passés, mais seulement "cartographiquement" :
#  ![image.png](attachment:image.png)

# %% [markdown]
# Nouvelle étude qui tackle le problème comme ça nous intéresse : [Temperature and humidity based projections of a
# rapid rise in global heat stress exposure during the
# 21st century, Coffel et al., 2018](https://iopscience.iop.org/article/10.1088/1748-9326/aaa00e/pdf)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Avec la wet bulb temperature (WBT) telle que :
#
# ![image.png](attachment:image.png) ([Wikipédia](https://en.wikipedia.org/wiki/Wet-bulb_temperature))

# %% [markdown]
# Un peu difficile d'estimer, mais on ne peut pas

# %% [markdown]
# Hauteur de 5*10^8 de personnes-jours : 263 px
# RCP4.5:
#
# 2020 - 2030 : 0px
# 2030 - 2040 : 2px
# 2040 - 2050 : 6px
# 2050 - 2060 : 10px
# 2060 - 2070 : 19px
# 2070 - 2080 : 25px
#
# RCP8.5:
#
# 2020 - 2030 : 0px
# 2030 - 2040 : 3px
# 2040 - 2050 : 12px
# 2050 - 2060 : 54px
# 2060 - 2070 : 126px
# 2070 - 2080 : 245px

# %%
person_day_4_5_px = [0,2,6,10,19,25]
person_day_4_5 = [5*10**8 * x / 263 for x in person_day_4_5_px]
person_year_4_5 = [x / 365 for x in person_day_4_5] 
print(person_day_4_5, person_year_4_5)

person_day_8_5_px = [0,3,12,54,126,245]
person_day_8_5 = [5*10**8 * x / 263 for x in person_day_8_5_px]
person_year_8_5 = [x / 365 for x in person_day_8_5]
print(person_day_8_5, person_year_8_5)
# Out:
# [0.0, 3802281.3688212926, 11406844.106463877, 19011406.844106466, 36121673.003802285, 47528517.11026616] [0.0, 10417.209229647377, 31251.62768894213, 52086.04614823689, 98963.48768165009, 130215.1153705922]
# [0.0, 5703422.053231939, 22813688.212927755, 102661596.9581749, 239543726.23574144, 465779467.6806084] [0.0, 15625.813844471066, 62503.25537788426, 281264.64920047915, 656284.1814677848, 1276108.1306318038]

# %% [markdown]
# ça pourrait devenir signifiant, mais peu de chance que ça arrive dans le scénario 4.5, le plus représentatif. Même en estimant qu'on passe de 10 à 0 sur l'échelle de Cantrill à cause d'une température du themormètre mouillé dépassant 32°C, cela revient à perdre 5 écarts types, et donc, en 2080, 650 000 Wellbys/an. On rappelle que les Wellbys perdus à cause des morts prématurées sont de l'ODG de 10^7/an.

# %% [markdown]
# Autre méthode de calcul:

# %%
0.04 * 20 / 365 * (0.5-0.3) * 10**10

# Wellby perdu pour une température dépassant 32°C (déjà en écart-type) (Noelke et al) * 20 jours / 365 jours *-(proportion vivant au moins 20 jours au-delà du seuil mortel de température et d'humidité en 1975 - proportion de la population qui va vivre au moins 20 jours au-delà du seuil mortel de température et d'humidité d'ici à 2100 par an)(Mora et al.)* population mondiale en 2100
# Out:
# 4383561.643835617

# %% [markdown]
# Ordre de grandeur est le même, intéressant, mais surtout on a fait beaucoup de sous-estimations (les 4% de Wellbys sont juste pour 32°C, et on est mortel à cette température pour une humidité d'au moins 60%, en bref on peut s'attendre à plus de 4% de Wellbys perdus mais Noelke n'aborde pas ces climats tropicaux (étude menée aux US)). Et évidemment, les "au moins 20 jours" réduisent grandement ce chiffre, mais je n'ai pas pu avoir accès aux données de Mora et al.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Il faut vraisemblablement creuser, mais ça n'a pas l'air d'être négligeable comparé aux Wellbys perdus à cause des morts prématurées.
